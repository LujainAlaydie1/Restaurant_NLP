# %%
#libraries
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import pandas as pd

# %%
dataset_path = "preprocessed_resturants.csv"
df = pd.read_csv(dataset_path)

# %%
columns_to_drop = ['lat', 'lng', 'likes', 'photos', 'tips', 'ratingSignals']
# Drop the specified columns
df = df.drop(columns=columns_to_drop)

# Display the modified DataFrame
df.head()
# Out:
#                               name               categories  \
# 0                          Dunkin'               Donut Shop
# 1  Moroccan Taste (المذاق المغربي)                     Café
# 2                          كرك جدي                     Café
# 3        دانكن دونت طريق المزاحميه  Donut Shop, Coffee Shop
# 4                        Starbucks              Coffee Shop
#
#                                              address  price  rating
# 0                   الرياض, المملكة العربية السعودية  Cheap     8.9
# 1  Makkah Al Mukarramah Rd, الرياض, المملكة العرب...  Cheap     8.6
# 2                   الرياض, المملكة العربية السعودية  Cheap     7.3
# 3                   الرياض, المملكة العربية السعودية  Cheap     8.3
# 4             الرياض 14723, المملكة العربية السعودية  Cheap     8.1

# %%
len(df)
# Out:
# 7411

# %%
# Define a function to check if the string contains Arabic characters
def has_arabic(text):
    arabic_pattern = re.compile(r'[\u0600-\u06FF]+')
    return bool(arabic_pattern.search(text))

# Filter out rows where 'name' contains Arabic characters
df_cleaned = df[df['name'].apply(lambda x: not has_arabic(x))]

# Reset the index
df_cleaned = df_cleaned.reset_index(drop=True)

# Display the cleaned DataFrame
print(df_cleaned)
# Out:
#                                     name            categories  \
# 0                                Dunkin'            Donut Shop
# 1                              Starbucks           Coffee Shop
# 2                            Burger King  Fast Food Restaurant
# 3                              Starbucks           Coffee Shop
# 4                                    Tsc            Restaurant
# ...                                  ...                   ...
# 2202                      Domino's Pizza           Pizza Place
# 2203                         Upper Crust        Sandwich Place
# 2204                           Java Time           Coffee Shop
# 2205  Upper Crust- KKIA “Riyadh Airport”                  Café
# 2206                      MammaRoti cafe                  Café
#
#                                                 address     price  rating
# 0                      الرياض, المملكة العربية السعودية     Cheap     8.9
# 1                الرياض 14723, المملكة العربية السعودية     Cheap     8.1
# 2     prince mamdooh bin abdulaziz, Riyadh 12241, ال...     Cheap     6.7
# 3                      الرياض, المملكة العربية السعودية     Cheap     8.0
# 4       alshifa, الرياض 14725, المملكة العربية السعودية  Moderate     7.6
# ...                                                 ...       ...     ...
# 2202  King Khalid International Airport, Terminal 5,...     Cheap     7.1
# 2203                   الرياض, المملكة العربية السعودية     Cheap     5.3
# 2204  King Khalid International Airport (RUH), الريا...     Cheap     7.5
# 2205  King Khalid International Airport, الرياض, الم...     Cheap     5.1
# 2206  King khaled international airport, الرياض, الم...     Cheap     6.1
#
# [2207 rows x 5 columns]

# %%
#all lowercase
df_cleaned['name'] = df_cleaned['name'].str.lower()

# Remove entire rows with duplicate 'cleaned_name'
df_cleaned = df_cleaned.drop_duplicates(subset=['name'], keep='first')

# Reset the index
df_cleaned = df_cleaned.reset_index(drop=True)

# Display the cleaned DataFrame
print(df_cleaned)
# Out:
#                                     name            categories  \
# 0                                dunkin'            Donut Shop
# 1                              starbucks           Coffee Shop
# 2                            burger king  Fast Food Restaurant
# 3                                    tsc            Restaurant
# 4                         domino's pizza           Pizza Place
# ...                                  ...                   ...
# 1466                 arabica star coffee           Coffee Shop
# 1467              butlers chocolate café                  Café
# 1468                         upper crust        Sandwich Place
# 1469  upper crust- kkia “riyadh airport”                  Café
# 1470                      mammaroti cafe                  Café
#
#                                                 address     price  rating
# 0                      الرياض, المملكة العربية السعودية     Cheap     8.9
# 1                الرياض 14723, المملكة العربية السعودية     Cheap     8.1
# 2     prince mamdooh bin abdulaziz, Riyadh 12241, ال...     Cheap     6.7
# 3       alshifa, الرياض 14725, المملكة العربية السعودية  Moderate     7.6
# 4     Alshifaa Plaza (Imam Muslim), الرياض 14725, ال...     Cheap     7.3
# ...                                                 ...       ...     ...
# 1466      Qaseem Road, الرياض, المملكة العربية السعودية     Cheap     7.3
# 1467                   الرياض, المملكة العربية السعودية     Cheap     7.2
# 1468                   الرياض, المملكة العربية السعودية     Cheap     5.3
# 1469  King Khalid International Airport, الرياض, الم...     Cheap     5.1
# 1470  King khaled international airport, الرياض, الم...     Cheap     6.1
#
# [1471 rows x 5 columns]

# %%
df_cleaned.head()
# Out:
#              name            categories  \
# 0         dunkin'            Donut Shop
# 1       starbucks           Coffee Shop
# 2     burger king  Fast Food Restaurant
# 3             tsc            Restaurant
# 4  domino's pizza           Pizza Place
#
#                                              address     price  rating
# 0                   الرياض, المملكة العربية السعودية     Cheap     8.9
# 1             الرياض 14723, المملكة العربية السعودية     Cheap     8.1
# 2  prince mamdooh bin abdulaziz, Riyadh 12241, ال...     Cheap     6.7
# 3    alshifa, الرياض 14725, المملكة العربية السعودية  Moderate     7.6
# 4  Alshifaa Plaza (Imam Muslim), الرياض 14725, ال...     Cheap     7.3

# %%
df_cleaned[["cuisine1", "cuisine2",'cuisine3']] = (  # Create two new features
    df_cleaned["categories"]           # from the cuisine feature
    .str                         # through the string accessor
    .split(",", expand=True)     # by splitting on ","
                                 # and expanding the result into separate columns
)
# df.rename(columns ={'price for one': 'price'},inplace=True)
df_cleaned.head()
# Out:
#              name            categories  \
# 0         dunkin'            Donut Shop
# 1       starbucks           Coffee Shop
# 2     burger king  Fast Food Restaurant
# 3             tsc            Restaurant
# 4  domino's pizza           Pizza Place
#
#                                              address     price  rating  \
# 0                   الرياض, المملكة العربية السعودية     Cheap     8.9
# 1             الرياض 14723, المملكة العربية السعودية     Cheap     8.1
# 2  prince mamdooh bin abdulaziz, Riyadh 12241, ال...     Cheap     6.7
# 3    alshifa, الرياض 14725, المملكة العربية السعودية  Moderate     7.6
# 4  Alshifaa Plaza (Imam Muslim), الرياض 14725, ال...     Cheap     7.3
#
#                cuisine1 cuisine2 cuisine3
# 0            Donut Shop     None     None
# 1           Coffee Shop     None     None
# 2  Fast Food Restaurant     None     None
# 3            Restaurant     None     None
# 4           Pizza Place     None     None

# %%
features = ["cuisine1", "cuisine2",'cuisine3']

# %%
df_cleaned["temp"] = df_cleaned[features].isnull().sum(axis=1)
df_cleaned["no_Of_cusines"] = 3- df_cleaned["temp"]

# %%
df_cleaned.head()
# Out:
#              name            categories  \
# 0         dunkin'            Donut Shop
# 1       starbucks           Coffee Shop
# 2     burger king  Fast Food Restaurant
# 3             tsc            Restaurant
# 4  domino's pizza           Pizza Place
#
#                                              address     price  rating  \
# 0                   الرياض, المملكة العربية السعودية     Cheap     8.9
# 1             الرياض 14723, المملكة العربية السعودية     Cheap     8.1
# 2  prince mamdooh bin abdulaziz, Riyadh 12241, ال...     Cheap     6.7
# 3    alshifa, الرياض 14725, المملكة العربية السعودية  Moderate     7.6
# 4  Alshifaa Plaza (Imam Muslim), الرياض 14725, ال...     Cheap     7.3
#
#                cuisine1 cuisine2 cuisine3  temp  no_Of_cusines
# 0            Donut Shop     None     None     2              1
# 1           Coffee Shop     None     None     2              1
# 2  Fast Food Restaurant     None     None     2              1
# 3            Restaurant     None     None     2              1
# 4           Pizza Place     None     None     2              1

# %%
# Perform the search using boolean indexing
search_result = df_cleaned[df_cleaned['name'] == "kfc"]

# Print the search result
print(search_result)
# Out:
#   name                                 categories                   address  \
# 6  kfc  Fast Food Restaurant, Fried Chicken Joint  المملكة العربية السعودية
#
#    price  rating              cuisine1              cuisine2 cuisine3  temp  \
# 6  Cheap     6.6  Fast Food Restaurant   Fried Chicken Joint     None     1
#
#    no_Of_cusines
# 6              2

# %%
print(df_cleaned)
# Out:
#                                     name            categories  \
# 0                                dunkin'            Donut Shop
# 1                              starbucks           Coffee Shop
# 2                            burger king  Fast Food Restaurant
# 3                                    tsc            Restaurant
# 4                         domino's pizza           Pizza Place
# ...                                  ...                   ...
# 1466                 arabica star coffee           Coffee Shop
# 1467              butlers chocolate café                  Café
# 1468                         upper crust        Sandwich Place
# 1469  upper crust- kkia “riyadh airport”                  Café
# 1470                      mammaroti cafe                  Café
#
#                                                 address     price  rating  \
# 0                      الرياض, المملكة العربية السعودية     Cheap     8.9
# 1                الرياض 14723, المملكة العربية السعودية     Cheap     8.1
# 2     prince mamdooh bin abdulaziz, Riyadh 12241, ال...     Cheap     6.7
# 3       alshifa, الرياض 14725, المملكة العربية السعودية  Moderate     7.6
# 4     Alshifaa Plaza (Imam Muslim), الرياض 14725, ال...     Cheap     7.3
# ...                                                 ...       ...     ...
# 1466      Qaseem Road, الرياض, المملكة العربية السعودية     Cheap     7.3
# 1467                   الرياض, المملكة العربية السعودية     Cheap     7.2
# 1468                   الرياض, المملكة العربية السعودية     Cheap     5.3
# 1469  King Khalid International Airport, الرياض, الم...     Cheap     5.1
# 1470  King khaled international airport, الرياض, الم...     Cheap     6.1
#
#                   cuisine1 cuisine2 cuisine3  temp  no_Of_cusines
# 0               Donut Shop     None     None     2              1
# 1              Coffee Shop     None     None     2              1
# 2     Fast Food Restaurant     None     None     2              1
# 3               Restaurant     None     None     2              1
# 4              Pizza Place     None     None     2              1
# ...                    ...      ...      ...   ...            ...
# 1466           Coffee Shop     None     None     2              1
# 1467                  Café     None     None     2              1
# 1468        Sandwich Place     None     None     2              1
# 1469                  Café     None     None     2              1
# 1470                  Café     None     None     2              1
#
# [1471 rows x 10 columns]

# %%
df_cleaned.to_csv("resturants.csv", index=False)

# %%
# Assuming 'df' is your DataFrame with 'name', 'cuisine1', 'cuisine2', 'cuisine3' columns
features = df_cleaned[['cuisine1', 'cuisine2', 'cuisine3']].astype(str).apply(lambda x: ' '.join(x), axis=1).tolist()

# Create the TfidfVectorizer with multiple stop words for both Arabic and English
tfidf = TfidfVectorizer(stop_words= "english")
tfidf_matrix = tfidf.fit_transform(features)
similarity = cosine_similarity(tfidf_matrix)

# Create indices dictionary
indices = pd.Series(df_cleaned.index, index=df_cleaned['name']).to_dict()

# Example usage of the restaurant_recommendation function
def restaurant_recommendation(name, similarity_matrix=similarity, indices=indices):
    name = name.lower()

    if name not in indices:
        print(f"Error: {name} not found in the indices dictionary.")
        return pd.DataFrame()

    index = indices[name]
    similarity_scores = list(enumerate(similarity_matrix[index]))
    similarity_scores = sorted(similarity_scores, key=lambda x: x[1], reverse=True)

    # Exclude the input restaurant itself
    similarity_scores = similarity_scores[1:11] if len(similarity_scores) > 1 else similarity_scores

    restaurant_indices = [i[0] for i in similarity_scores]
    
    print(f"Similarity Scores: {similarity_scores}")
    
    return df_cleaned.iloc[restaurant_indices]


# Example usage
name_to_recommend = "Kfc"
recommendations = restaurant_recommendation(name_to_recommend)

# Define the desired columns
columns_to_display = ['name', 'address', 'price', 'rating', 'cuisine1', 'cuisine2', 'cuisine3']

# Filter and display relevant columns
formatted_recommendations = recommendations[columns_to_display]

# Filter and display relevant columns
formatted_recommendations = recommendations[columns_to_display]

# Print the custom-formatted table
for _, row in formatted_recommendations.iterrows():
    print(f"Name: {row['name']}")
    print(f"Address: {row['address']}")
    print(f"Price: {row['price']}")
    print(f"Rating: {row['rating']}")
    print(f"Cuisine 1: {row['cuisine1']}")
    print(f"Cuisine 2: {row['cuisine2']}")
    print(f"Cuisine 3: {row['cuisine3']}")
    print('-' * 10)  # Separator for better readability
# Out:
# Similarity Scores: [(100, 1.0000000000000002), (635, 1.0000000000000002), (390, 0.8716060539559102), (84, 0.8228131921947772), (583, 0.8228131921947772), (648, 0.8228131921947772), (729, 0.8228131921947772), (810, 0.8228131921947772), (1082, 0.8228131921947772), (1300, 0.8228131921947772)]
# Name: shallal restaurant
# Address: Mansoura District (Kharj Road), الرياض, المملكة العربية السعودية
# Price: Cheap
# Rating: 8.2
# Cuisine 1: Fried Chicken Joint
# Cuisine 2:  Fast Food Restaurant
# Cuisine 3: None
# ----------
# Name: texas chicken
# Address: King Abdullah Rd., الرياض, المملكة العربية السعودية
# Price: Cheap
# Rating: 6.4
# Cuisine 1: Fast Food Restaurant
# Cuisine 2:  Fried Chicken Joint
# Cuisine 3: None
# ----------
# Name: japang
# Address: الرياض 12221, المملكة العربية السعودية
# Price: Cheap
# Rating: 4.8
# Cuisine 1: Fried Chicken Joint
# Cuisine 2:  Japanese Restaurant
# Cuisine 3:  Fast Food Restaurant
# ----------
# Name: broasted al najah
# Address: As Suwaidi Al Am. (Kaab Bin Zuhair St.), الرياض, المملكة العربية السعودية
# Price: Cheap
# Rating: 8.0
# Cuisine 1: Fried Chicken Joint
# Cuisine 2: None
# Cuisine 3: None
# ----------
# Name: casho
# Address: King Abdullah Road, الرياض 12343, المملكة العربية السعودية
# Price: Cheap
# Rating: 7.6
# Cuisine 1: Fried Chicken Joint
# Cuisine 2: None
# Cuisine 3: None
# ----------
# Name: chick-n-bun
# Address: الرياض 13213, المملكة العربية السعودية
# Price: Cheap
# Rating: 7.8
# Cuisine 1: Fried Chicken Joint
# Cuisine 2: None
# Cuisine 3: None
# ----------
# Name: raising cane's
# Address: Riyadh Gallery, الرياض 12262, المملكة العربية السعودية
# Price: Cheap
# Rating: 9.0
# Cuisine 1: Fried Chicken Joint
# Cuisine 2: None
# Cuisine 3: None
# ----------
# Name: raising cane's - riyadh park mall
# Address: Riyadh Park, الرياض 13511, المملكة العربية السعودية
# Price: Cheap
# Rating: 8.0
# Cuisine 1: Fried Chicken Joint
# Cuisine 2: None
# Cuisine 3: None
# ----------
# Name: chkn pop-up
# Address: Gernatah Square (Exit 9), الرياض 13241, المملكة العربية السعودية
# Price: Cheap
# Rating: 9.1
# Cuisine 1: Fried Chicken Joint
# Cuisine 2: None
# Cuisine 3: None
# ----------
# Name: broaster
# Address: الرياض 13316, المملكة العربية السعودية
# Price: Cheap
# Rating: 5.7
# Cuisine 1: Fried Chicken Joint
# Cuisine 2: None
# Cuisine 3: None
# ----------
